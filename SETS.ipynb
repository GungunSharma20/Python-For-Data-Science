# %% [markdown]
# SETS
# Sets are used to store multiple items in a single variable.
#
# Set is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Tuple, and Dictionary, all with different qualities and usage.
#
# A set is a collection which is unordered, unchangeable*, and unindexed.
# Note: Set items are unchangeable, but you can remove items and add new items.

# %%
s={1,2,3,4,5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(type(s))
# Out:
# <class 'set'>

# %%
s={1,2,3,4,5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(len(s))
# Out:
# 5

# %%
s2={"A",1,2,"B",True,1}
print(s2)
# Out:
# {1, 2, 'A', 'B'}

# %%
A={"Apple","Banana","orange"}
B={1,5,3,4,2}
C={True,False,False}
print(A)
print(B)
print(C)
# Out:
# {'Banana', 'Apple', 'orange'}
# {1, 2, 3, 4, 5}
# {False, True}

# %%
s4={"abc",45,False,32,"abc"}
s4
# Out:
# {32, 45, False, 'abc'}

# %% [markdown]
# # Access items in set

# %%
s={1,2,3,4,5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(5 in s)
# Out:
# True

# %%
print(9 in s)
# Out:
# False

# %%
print(7 not in s)
# Out:
# True

# %%
s={1,2,3,4,5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s.add(6)
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s.remove(5)
print(s)
# Out:
# {1, 2, 3, 4, 6}

# %% [markdown]
# # Add items

# %%
s={1,2,3,4,5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s.add(6)
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s5={4,5,6,7}
s.update(s5)
s
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s={"a","b","c"}
s1={"d","e","f"}
s.update(s1)
s
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f'}

# %%
l=[8,9,10]
s.update(l)
s
# Out:
# {10, 8, 9, 'a', 'b', 'c', 'd', 'e', 'f'}

# %%
list=["A","B"]
s5.update(list)
s5
# Out:
# {4, 5, 6, 7, 'A', 'B'}

# %% [markdown]
# # remove items

# %%
s5.remove(5)
s5
# Out:
# {4, 6, 7, 'A', 'B'}

# %%
s5.discard(7)
s5
# Out:
# {4, 6, 'A', 'B'}

# %%
s5.pop()
s5
# Out:
# {6, 'A', 'B'}

# %%
s6={1,2,3}
s6.clear()
s6
# Out:
# set()

# %%
s7={1,2}
s7.delete()
s7
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-8b7df89fa113> in <cell line: 2>()
#       1 s7={1,2}
# ----> 2 s7.delete()
#       3 s7
#
# AttributeError: 'set' object has no attribute 'delete'

# %% [markdown]
# ## LOOPS ITEMS

# %%
items={'radha','isha','komal'}
for x in items:
  print(x)
# Out:
# radha
# komal
# isha

# %% [markdown]
# # join by union in sets

# %%
s={1,2,3}
s2={"A","B","C"}
s4={4,5,6}
s5={7,8,9}
s3=s.union(s,s2,s4,s5)
s3
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 'A', 'B', 'C'}

# %%
s={4,5,6,7,8}
s1={3,4,5,6,8}
s3=s.intersection(s1)
print(s3)
# Out:
# {8, 4, 5, 6}

# %%
s5={1,2,3,6}
s7={1,2,3,4,5}
s3=s5& s7
print(s3)
# Out:
# {1, 2, 3}

# %%
s3=s7.difference(s5)
print(s3)
# Out:
# {4, 5}

# %%
s3=s5-s7
print(s3)
# Out:
# {6}
