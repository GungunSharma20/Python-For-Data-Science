# %% [markdown]
# ## STRING
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# 'hello' is the same as "hello".
#
# You can display a string literal with the print() function:

# %%
b="hello aaft"
print(b)
# Out:
# hello aaft

# %%
a="""Python is a high-level,
general-purpose programming language"""
print(a)
# Out:
# Python is a high-level,
# general-purpose programming language

# %%
a="""     python is case sensitive language.
     i am learning stings methods."""
print(a)
# Out:
#      python is case sensitive language.
#      i am learning stings methods.

# %% [markdown]
# # SLICING

# %%
print(b[1])
# Out:
# e

# %%
print(b[6])
# Out:
# a

# %%
print(b[6:])
# Out:
# aaft

# %%
print(b[:5])
# Out:
# hello

# %%
print(b[:])
# Out:
# hello aaft

# %%
print(b[-4:])
# Out:
# aaft

# %%
print(b[-10:])
# Out:
# hello aaft

# %%
print(type(b))
# Out:
# <class 'str'>

# %% [markdown]
# # for capital letters

# %%
print(b.upper())
# Out:
# HELLO AAFT

# %% [markdown]
# ## for small letters

# %%
print(b.lower())
# Out:
# hello aaft

# %%
a="hello"
b="world"
c=a+b
c=a+" "+b
print(c)
# Out:
# hello world

# %%
b = b.capitalize()
print(b)
# Out:
# World

# %%
a='hello,world!'
print(a.strip())
# Out:
# hello,world!

# %% [markdown]
# # REPLACING STRING

# %%
a="Hello,World!"
print(a.replace("H","K"))
# Out:
# Kello,World!

# %% [markdown]
# # SPLIT STRING

# %%
a="Hello World"
print(a.split(","))
# Out:
# ['Hello World']

# %% [markdown]
# ## String Concatenation

# %%
a="Gungun"
b="Sharma"
c=a+b
print(c)
# Out:
# GungunSharma

# %%
# To add a space between them, add a " ":

# %%
a="Gungun"
b="Sharma"
c=a+" "+b
print(c)
# Out:
# Gungun Sharma

# %%
age=19
txt='my name is gungun,i am' + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-f616c677c472> in <cell line: 2>()
#       1 age=19
# ----> 2 txt='my name is gungun,i am' + age
#       3 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # F STRING
# To specify a string as an f-string, simply put an f in front of the string literal, and add curly brackets {} as placeholders for variables and other operations.

# %%
age = 36
txt = f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %% [markdown]
# # Placeholders and Modifiers
# A placeholder can contain variables, operations, functions, and modifiers to format the value.

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %% [markdown]
# To fix this problem, use the escape character \"
#
# The escape character allows you to use double quotes when you normally would not be allowed

# %%
txt = "We are the so-called "Vikings" from the north."
print(txt)
# Out:
#   File "<ipython-input-1-485014d8dfdf>", line 1
#     txt = "We are the so-called "Vikings" from the north."
#                                  ^
# SyntaxError: invalid syntax

# %%
txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %%
txt="My name is \"GunGun\".I am from Delhi."
print(txt)
# Out:
# My name is "GunGun".I am from Delhi.
