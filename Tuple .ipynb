# %%
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members.

# %%
Tuple=(1,2,3,4)
print(Tuple)
# Out:
# (1, 2, 3, 4)

# %%
print(type(T))
# Out:
# <class 'tuple'>

# %%
print(len(T))
# Out:
# 4

# %%
T1=("A","B","C","D")
T2=(1,2,3,4)
T3=(True,False,True)
print(T1)
print(T2)
print(T3)
# Out:
# ('A', 'B', 'C', 'D')
# (1, 2, 3, 4)
# (True, False, True)

# %%
print(type(T1))
print(type(T2))
print(type(T3))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
print(len(T1))
print(len(T2))
print(len(T3))
# Out:
# 4
# 4
# 3

# %%
# access tuple items.

# %%
t1=(25,45,36,75,85,14,12)
print(t1)
# Out:
# (25, 45, 36, 75, 85, 14, 12)

# %%
print(t1[2])
# Out:
# 36

# %%
print(t1[2:5])
# Out:
# (36, 75, 85)

# %%
print(t1[2:])
# Out:
# (36, 75, 85, 14, 12)

# %%
# negative indexing

# %%
print(t1[-4])
# Out:
# 75

# %%
print(t1[-5:-2])
# Out:
# (36, 75, 85)

# %%
print(t1[-6:])
# Out:
# (45, 36, 75, 85, 14, 12)

# %%
print(t1[:])
# Out:
# (25, 45, 36, 75, 85, 14, 12)

# %%
# changing tuple items to convert tuple items into a list.

# %%
t2=("Apple","Banana","Mango")
print(t2)
# Out:
# ('Apple', 'Banana', 'Mango')

# %%
x=list(t2)
x[1]="Kiwi"
t2=tuple(x)
print(t2)
# Out:
# ('Apple', 'Kiwi', 'Mango')

# %%
x=(1,2,3,4)
y=list(x)
y[2]=5
print(y)
# Out:
# [1, 2, 5, 4]

# %%
x=tuple(y)
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-872f1792d5e4> in <cell line: 1>()
# ----> 1 x=tuple(y)
#       2 print(x)
#
# TypeError: 'tuple' object is not callable

# %%
x=(4,5,6,7)
t2=list(x)
t2[2]=4
x=tuple(t2)
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-5989f6444e9b> in <cell line: 4>()
#       2 t2=list(x)
#       3 t2[2]=4
# ----> 4 x=tuple(t2)
#       5 print(x)
#
# TypeError: 'tuple' object is not callable

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-1c2e8c6bb52c> in <cell line: 1>()
# ----> 1 x=tuple(t2)
#       2 print(x)
#
# TypeError: 'tuple' object is not callable

# %%
|x=(1,2,3,4)
x=list(y)
y.append(6)
y=tuple(x)
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-bab583c8d2c0> in <cell line: 4>()
#       2 x=list(y)
#       3 y.append(6)
# ----> 4 y=tuple(x)
#       5 print(x)
#
# TypeError: 'tuple' object is not callable

# %%
x=("orange","apple","banana")
y=list(x)
x.append("kivi")
y=tuple(x)
print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-48426201ec49> in <cell line: 3>()
#       1 x=("orange","apple","banana")
#       2 y=list(x)
# ----> 3 x.append("kivi")
#       4 y=tuple(x)
#       5 print(x)
#
# AttributeError: 'tuple' object has no attribute 'append'
